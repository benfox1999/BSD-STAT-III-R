# %%
library(ISLR)
library(ggplot2)

# %%
data(Auto)
colnames(Auto)
# Out:
# [1] "mpg"          "cylinders"    "displacement" "horsepower"   "weight"
# [6] "acceleration" "year"         "origin"       "name"

# %%
fit = lm(Auto$acceleration ~ Auto$weight + Auto$horsepower)
summary(fit)
# Out:
# Call:
# lm(formula = Auto$acceleration ~ Auto$weight + Auto$horsepower)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.2802 -1.1236 -0.2544  0.9128  7.1814
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)     18.4357912  0.3264888   56.47   <2e-16 ***
# Auto$weight      0.0023018  0.0002068   11.13   <2e-16 ***
# Auto$horsepower -0.0933128  0.0045628  -20.45   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.745 on 389 degrees of freedom
# Multiple R-squared:  0.6018,	Adjusted R-squared:  0.5998
# F-statistic:   294 on 2 and 389 DF,  p-value: < 2.2e-16

# %%
par(bg = "white")
plot(Auto$weight, Auto$acceleration)
# Out:
# plot without title

# %%
fit2 = lm(Auto$acceleration ~ Auto$weight)
summary(fit2)
# Out:
# Call:
# lm(formula = Auto$acceleration ~ Auto$weight)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.6865 -1.7250 -0.2124  1.4477  9.5463
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 19.5726658  0.4628601  42.286   <2e-16 ***
# Auto$weight -0.0013539  0.0001495  -9.056   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.511 on 390 degrees of freedom
# Multiple R-squared:  0.1738,	Adjusted R-squared:  0.1716
# F-statistic: 82.01 on 1 and 390 DF,  p-value: < 2.2e-16

# %%
cor(Auto$weight, Auto$acceleration)
fit2$coefficients
# Out:
# [1] -0.4168392
#  (Intercept)  Auto$weight
# 19.572665810 -0.001353896

# %%
ggplot(Auto, aes(x=weight, y=acceleration, col=horsepower))+geom_point()+
  scale_color_gradientn(colors=rainbow(5))
# Out:
# plot without title

# %%
ind = which(Auto$horsepower>= 40 & Auto$horsepower<=60)
par(bg = "white")
plot(Auto$weight[ind], Auto$acceleration[ind])
# Out:
# plot without title
